# %% [markdown]
# # Generative Adversarial Networks (GAN) example in PyTorch.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable

# %% [markdown]
# ## Hyperparameters

# %%
# Data params
data_mean = 4
data_stddev = 1.25

# Model params
g_input_size = 1     # Random noise dimension coming into generator, per output vector
g_hidden_size = 50   # Generator complexity
g_output_size = 1    # size of generated output vector
d_input_size = 100   # Minibatch size - cardinality of distributions
d_hidden_size = 50   # Discriminator complexity
d_output_size = 1    # Single dimension for 'real' vs. 'fake'
minibatch_size = d_input_size

d_learning_rate = 2e-4  # 2e-4
g_learning_rate = 2e-4
optim_betas = (0.9, 0.999)
num_epochs = 30000
print_interval = 200
d_steps = 1  # k >= 1
g_steps = 1

# %% [markdown]
# ## Data loader

# %%
def get_distribution_sampler(mu, sigma):
    return lambda n: torch.Tensor(np.random.normal(mu, sigma, (1, n)))  # Gaussian

def get_generator_input_sampler():
    return lambda m, n: torch.rand(m, n)  # Uniform-dist data into generator, _NOT_ Gaussian

# preprocess, d_input_func = lambda data: data, lambda x: x)
preprocess, d_input_func = lambda data: decorate_with_diffs(data, 2.0), lambda x: x * 2

def normal(mu, sigma):
    return lambda n: torch.Tensor(np.random.normal(mu, sigma, (1, n))) # gaussian noise

def entropy():
    return lambda m, n: torch.rand(m, n) # uniform noise

def extract(v):
    return v.data.storage().tolist()

def stats(d):
    return [np.mean(d), np.std(d)]

def decorate_with_diffs(data, exponent):
    mean = torch.mean(data.data, 1)
    mean_broadcast = torch.mul(torch.ones(data.size()), mean.tolist()[0][0])
    diffs = torch.pow(data - Variable(mean_broadcast), exponent)
    return torch.cat([data, diffs], 1)

# %%
class Generator(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(Generator, self).__init__()
        self.map1 = nn.Linear(input_size, hidden_size)
        self.map2 = nn.Linear(hidden_size, hidden_size)
        self.map3 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = F.elu(self.map1(x))
        x = F.sigmoid(self.map2(x))
        return self.map3(x)

class Discriminator(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(Discriminator, self).__init__()
        self.map1 = nn.Linear(input_size, hidden_size)
        self.map2 = nn.Linear(hidden_size, hidden_size)
        self.map3 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = F.elu(self.map1(x))
        x = F.elu(self.map2(x))
        return F.sigmoid(self.map3(x))

# %%
d_sampler = get_distribution_sampler(data_mean, data_stddev)
gi_sampler = get_generator_input_sampler()
G = Generator(input_size=g_input_size, hidden_size=g_hidden_size, output_size=g_output_size)
D = Discriminator(input_size=d_input_func(d_input_size), hidden_size=d_hidden_size, output_size=d_output_size)
criterion = nn.BCELoss()  # Binary cross entropy: http://pytorch.org/docs/nn.html#bceloss
d_optimizer = optim.Adam(D.parameters(), lr=d_learning_rate, betas=optim_betas)
g_optimizer = optim.Adam(G.parameters(), lr=g_learning_rate, betas=optim_betas)

# %%
for epoch in range(num_epochs):
    for d_index in range(d_steps):
        # 1. Train D on real+fake
        D.zero_grad()

        #  1A: Train D on real
        d_real_data = Variable(d_sampler(d_input_size))
        d_real_decision = D(preprocess(d_real_data))
        print(d_real_decision.data)
        d_real_error = criterion(d_real_decision, Variable(torch.ones(1)))  # ones = true
        d_real_error.backward() # compute/store gradients, but don't change params

        #  1B: Train D on fake
        d_gen_input = Variable(gi_sampler(minibatch_size, g_input_size))
        d_fake_data = G(d_gen_input).detach()  # detach to avoid training G on these labels
        d_fake_decision = D(preprocess(d_fake_data.t()))
        d_fake_error = criterion(d_fake_decision, Variable(torch.zeros(1)))  # zeros = fake
        d_fake_error.backward()
        d_optimizer.step()     # Only optimizes D's parameters; changes based on stored gradients from backward()

    for g_index in range(g_steps):
        # 2. Train G on D's response (but DO NOT train D on these labels)
        G.zero_grad()

        gen_input = Variable(gi_sampler(minibatch_size, g_input_size))
        g_fake_data = G(gen_input)
        dg_fake_decision = D(preprocess(g_fake_data.t()))
        g_error = criterion(dg_fake_decision, Variable(torch.ones(1)))  # we want to fool, so pretend it's all genuine

        g_error.backward()
        g_optimizer.step()  # Only optimizes G's parameters

    if epoch % print_interval == 0:
        print("%s: D: %s/%s G: %s (Real: %s, Fake: %s) " % (epoch,
                                                            extract(d_real_error)[0],
                                                            extract(d_fake_error)[0],
                                                            extract(g_error)[0],
                                                            stats(extract(d_real_data)),
                                                            stats(extract(d_fake_data))))
# Out:
#  0.9989
# [torch.FloatTensor of size 1x1]
#
# 0: D: 0.0011032943148165941/0.031091857701539993 G: 3.8190414905548096 (Real: [4.0715127182006832, 1.2866877137199169], Fake: [0.41409335136413572, 0.17117764882776262])
#
#  0.9993
# [torch.FloatTensor of size 1x1]
#
#
#  0.9953
# [torch.FloatTensor of size 1x1]
#
#
#  0.9938
# [torch.FloatTensor of size 1x1]
#
#
#  0.9998
# [torch.FloatTensor of size 1x1]
#
#
#  0.9985
# [torch.FloatTensor of size 1x1]
#
#
#  0.9992
# [torch.FloatTensor of size 1x1]
#
#
#  0.9996
# [torch.FloatTensor of size 1x1]
#
#
#  0.9991
# [torch.FloatTensor of size 1x1]
#
#
#  0.9975
# [torch.FloatTensor of size 1x1]
#
#
#  0.9989
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9988
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9958
# [torch.FloatTensor of size 1x1]
#
#
#  0.9984
# [torch.FloatTensor of size 1x1]
#
#
#  0.9986
# [torch.FloatTensor of size 1x1]
#
#
#  0.9685
# [torch.FloatTensor of size 1x1]
#
#
#  0.9994
# [torch.FloatTensor of size 1x1]
#
#
#  0.9974
# [torch.FloatTensor of size 1x1]
#
#
#  0.9941
# [torch.FloatTensor of size 1x1]
#
#
#  0.9976
# [torch.FloatTensor of size 1x1]
#
#
#  0.9997
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9997
# [torch.FloatTensor of size 1x1]
#
#
#  0.9921
# [torch.FloatTensor of size 1x1]
#
#
#  0.9994
# [torch.FloatTensor of size 1x1]
#
#
#  0.9998
# [torch.FloatTensor of size 1x1]
#
#
#  0.9997
# [torch.FloatTensor of size 1x1]
#
#
#  0.9932
# [torch.FloatTensor of size 1x1]
#
#
#  0.9133
# [torch.FloatTensor of size 1x1]
#
#
#  0.9973
# [torch.FloatTensor of size 1x1]
#
#
#  0.9996
# [torch.FloatTensor of size 1x1]
#
#
#  0.9984
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9994
# [torch.FloatTensor of size 1x1]
#
#
#  0.9982
# [torch.FloatTensor of size 1x1]
#
#
#  0.9915
# [torch.FloatTensor of size 1x1]
#
#
#  0.9997
# [torch.FloatTensor of size 1x1]
#
#
#  0.9994
# [torch.FloatTensor of size 1x1]
#
#
#  0.9994
# [torch.FloatTensor of size 1x1]
#
#
#  0.9995
# [torch.FloatTensor of size 1x1]
#
#
#  0.9917
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9993
# [torch.FloatTensor of size 1x1]
#
#
#  0.9981
# [torch.FloatTensor of size 1x1]
#
#
#  0.9997
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9998
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9997
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9998
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9995
# [torch.FloatTensor of size 1x1]
#
#
#  0.9995
# [torch.FloatTensor of size 1x1]
#
#
#  0.9907
# [torch.FloatTensor of size 1x1]
#
#
#  0.9972
# [torch.FloatTensor of size 1x1]
#
#
#  0.9976
# [torch.FloatTensor of size 1x1]
#
#
#  0.9983
# [torch.FloatTensor of size 1x1]
#
#
#  0.9991
# [torch.FloatTensor of size 1x1]
#
#
#  0.9455
# [torch.FloatTensor of size 1x1]
#
#
#  0.8414
# [torch.FloatTensor of size 1x1]
#
#
#  0.9639
# [torch.FloatTensor of size 1x1]
#
#
#  0.9935
# [torch.FloatTensor of size 1x1]
#
#
#  0.9878
# [torch.FloatTensor of size 1x1]
#
#
#  0.9982
# [torch.FloatTensor of size 1x1]
#
#
#  0.9988
# [torch.FloatTensor of size 1x1]
#
#
#  0.9960
# [torch.FloatTensor of size 1x1]
#
#
#  0.9998
# [torch.FloatTensor of size 1x1]
#
#
#  0.9997
# [torch.FloatTensor of size 1x1]
#
#
#  0.9980
# [torch.FloatTensor of size 1x1]
#
#
#  0.9865
# [torch.FloatTensor of size 1x1]
#
#
#  0.9992
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9991
# [torch.FloatTensor of size 1x1]
#
#
#  0.9970
# [torch.FloatTensor of size 1x1]
#
#
#  0.9941
# [torch.FloatTensor of size 1x1]
#
#
#  0.9995
# [torch.FloatTensor of size 1x1]
#
#
#  0.9992
# [torch.FloatTensor of size 1x1]
#
#
#  0.9976
# [torch.FloatTensor of size 1x1]
#
#
#  0.9978
# [torch.FloatTensor of size 1x1]
#
#
#  0.9983
# [torch.FloatTensor of size 1x1]
#
#
#  0.9941
# [torch.FloatTensor of size 1x1]
#
#
#  0.9966
# [torch.FloatTensor of size 1x1]
#
#
#  0.9968
# [torch.FloatTensor of size 1x1]
#
#
#  0.9907
# [torch.FloatTensor of size 1x1]
#
#
#  0.9995
# [torch.FloatTensor of size 1x1]
#
#
#  0.9929
# [torch.FloatTensor of size 1x1]
#
#
#  0.9972
# [torch.FloatTensor of size 1x1]
#
#
#  0.8942
# [torch.FloatTensor of size 1x1]
#
#
#  0.9739
# [torch.FloatTensor of size 1x1]
#
#
#  0.9888
# [torch.FloatTensor of size 1x1]
#
#
#  0.9973
# [torch.FloatTensor of size 1x1]
#
#
#  0.9993
# [torch.FloatTensor of size 1x1]
#
#
#  0.9974
# [torch.FloatTensor of size 1x1]
#
#
#  0.9985
# [torch.FloatTensor of size 1x1]
#
#
#  0.9989
# [torch.FloatTensor of size 1x1]
#
#
#  0.9974
# [torch.FloatTensor of size 1x1]
#
#
#  0.9981
# [torch.FloatTensor of size 1x1]
#
#
#  0.9975
# [torch.FloatTensor of size 1x1]
#
#
#  0.9988
# [torch.FloatTensor of size 1x1]
#
# 200: D: 0.0011573572410270572/0.03839118406176567 G: 2.8784608840942383 (Real: [4.1495580324530605, 1.3891364016278851], Fake: [0.92899468094110493, 0.3804277630703925])
#
#  0.9995
# [torch.FloatTensor of size 1x1]
#
#
#  0.9991
# [torch.FloatTensor of size 1x1]
#
#
#  0.9967
# [torch.FloatTensor of size 1x1]
#
#
#  0.9955
# [torch.FloatTensor of size 1x1]
#
#
#  0.9998
# [torch.FloatTensor of size 1x1]
#
#
#  0.9993
# [torch.FloatTensor of size 1x1]
#
#
#  0.9987
# [torch.FloatTensor of size 1x1]
#
#
#  0.9678
# [torch.FloatTensor of size 1x1]
#
#
#  0.9936
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9934
# [torch.FloatTensor of size 1x1]
#
#
#  0.9886
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9757
# [torch.FloatTensor of size 1x1]
#
#
#  0.9977
# [torch.FloatTensor of size 1x1]
#
#
#  0.9997
# [torch.FloatTensor of size 1x1]
#
#
#  0.9923
# [torch.FloatTensor of size 1x1]
#
#
#  0.9995
# [torch.FloatTensor of size 1x1]
#
#
#  0.9971
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9988
# [torch.FloatTensor of size 1x1]
#
#
#  0.9922
# [torch.FloatTensor of size 1x1]
#
#
#  0.9995
# [torch.FloatTensor of size 1x1]
#
#
#  0.9885
# [torch.FloatTensor of size 1x1]
#
#
#  0.9987
# [torch.FloatTensor of size 1x1]
#
#
#  0.9961
# [torch.FloatTensor of size 1x1]
#
#
#  0.9996
# [torch.FloatTensor of size 1x1]
#
#
#  0.9994
# [torch.FloatTensor of size 1x1]
#
#
#  0.9984
# [torch.FloatTensor of size 1x1]
#
#
#  0.9975
# [torch.FloatTensor of size 1x1]
#
#
#  0.9971
# [torch.FloatTensor of size 1x1]
#
#
#  0.9994
# [torch.FloatTensor of size 1x1]
#
#
#  0.9993
# [torch.FloatTensor of size 1x1]
#
#
#  0.8374
# [torch.FloatTensor of size 1x1]
#  0.9687
# [torch.FloatTensor of size 1x1]
#
#
#  0.9985
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9992
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9987
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9994
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9996
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9821
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9994
# [torch.FloatTensor of size 1x1]
#
#
#  0.9998
# [torch.FloatTensor of size 1x1]
#
#
#  0.9972
# [torch.FloatTensor of size 1x1]
#
#
#  0.9796
# [torch.FloatTensor of size 1x1]
#
#
#  0.9954
# [torch.FloatTensor of size 1x1]
#
#
#  0.9962
# [torch.FloatTensor of size 1x1]
#
#
#  0.9987
# [torch.FloatTensor of size 1x1]
#
#
#  0.9970
# [torch.FloatTensor of size 1x1]
#
#
#  0.9931
# [torch.FloatTensor of size 1x1]
#
#
#  0.9778
# [torch.FloatTensor of size 1x1]
#
#
#  0.9965
# [torch.FloatTensor of size 1x1]
#
#
#  0.9807
# [torch.FloatTensor of size 1x1]
#
#
#  0.9857
# [torch.FloatTensor of size 1x1]
#
#
#  0.9845
# [torch.FloatTensor of size 1x1]
#
#
#  0.9946
# [torch.FloatTensor of size 1x1]
#
#
#  0.9931
# [torch.FloatTensor of size 1x1]
#
#
#  0.9967
# [torch.FloatTensor of size 1x1]
#
#
#  0.9889
# [torch.FloatTensor of size 1x1]
#
#
#  0.9969
# [torch.FloatTensor of size 1x1]
#
#
#  0.9995
# [torch.FloatTensor of size 1x1]
#
#
#  0.9977
# [torch.FloatTensor of size 1x1]
#
#
#  0.9994
# [torch.FloatTensor of size 1x1]
#
#
#  0.9998
# [torch.FloatTensor of size 1x1]
#
#
#  0.9839
# [torch.FloatTensor of size 1x1]
#
#
#  0.9987
# [torch.FloatTensor of size 1x1]
#
#
#  0.9991
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9998
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9998
# [torch.FloatTensor of size 1x1]
#
#
#  0.9994
# [torch.FloatTensor of size 1x1]
#
#
#  0.9992
# [torch.FloatTensor of size 1x1]
#
#
#  0.9981
# [torch.FloatTensor of size 1x1]
#
#
#  0.9992
# [torch.FloatTensor of size 1x1]
#
#
#  0.9935
# [torch.FloatTensor of size 1x1]
#
#
#  0.9997
# [torch.FloatTensor of size 1x1]
#
#
#  0.9974
# [torch.FloatTensor of size 1x1]
#
#
#  0.9998
# [torch.FloatTensor of size 1x1]
#
#
#  0.9981
# [torch.FloatTensor of size 1x1]
#
#
#  0.9927
# [torch.FloatTensor of size 1x1]
#
#
#  0.9950
# [torch.FloatTensor of size 1x1]
#
#
#  0.9968
# [torch.FloatTensor of size 1x1]
#
#
#  0.9521
# [torch.FloatTensor of size 1x1]
#
#
#  0.9995
# [torch.FloatTensor of size 1x1]
#
#
#  0.9932
# [torch.FloatTensor of size 1x1]
#
#
#  0.9942
# [torch.FloatTensor of size 1x1]
#
#
#  0.9925
# [torch.FloatTensor of size 1x1]
#
#
#  0.9998
# [torch.FloatTensor of size 1x1]
#
#
#  0.9905
# [torch.FloatTensor of size 1x1]
#
#
#  0.9989
# [torch.FloatTensor of size 1x1]
#
#
#  0.9953
# [torch.FloatTensor of size 1x1]
#
#
#  0.9975
# [torch.FloatTensor of size 1x1]
#
#
#  0.9997
# [torch.FloatTensor of size 1x1]
#
#
#  0.9866
# [torch.FloatTensor of size 1x1]
#
#
#  0.9940
# [torch.FloatTensor of size 1x1]
#
#
#  0.9708
# [torch.FloatTensor of size 1x1]
#
#
#  0.9978
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9995
# [torch.FloatTensor of size 1x1]
#
#
#  0.9994
# [torch.FloatTensor of size 1x1]
#
#
#  0.9855
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9997
# [torch.FloatTensor of size 1x1]
#
#
#  0.9981
# [torch.FloatTensor of size 1x1]
#
#
#  0.9655
# [torch.FloatTensor of size 1x1]
#
#
#  0.9976
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9989
# [torch.FloatTensor of size 1x1]
#
#
#  0.9979
# [torch.FloatTensor of size 1x1]
#
#
#  0.9997
# [torch.FloatTensor of size 1x1]
#
#
#  0.9919
# [torch.FloatTensor of size 1x1]
#
#
#  0.9457
# [torch.FloatTensor of size 1x1]
#
#
#  0.9921
# [torch.FloatTensor of size 1x1]
#
#
#  0.9961
# [torch.FloatTensor of size 1x1]
#
#
#  0.9907
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9990
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9808
# [torch.FloatTensor of size 1x1]
#
#
#  0.9543
# [torch.FloatTensor of size 1x1]
#
#
#  0.9619
# [torch.FloatTensor of size 1x1]
#
#
#  0.9946
# [torch.FloatTensor of size 1x1]
#
#
#  0.9958
# [torch.FloatTensor of size 1x1]
#
#
#  0.9868
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9972
# [torch.FloatTensor of size 1x1]
#
#
#  0.9913
# [torch.FloatTensor of size 1x1]
#
#
#  0.6866
# [torch.FloatTensor of size 1x1]
#
#
#  0.9992
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9998
# [torch.FloatTensor of size 1x1]
#
#
#  0.9993
# [torch.FloatTensor of size 1x1]
#
#
#  0.9995
# [torch.FloatTensor of size 1x1]
#
#
#  0.9992
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9983
# [torch.FloatTensor of size 1x1]
#
#
#  0.9997
# [torch.FloatTensor of size 1x1]
#
#
#  0.9767
# [torch.FloatTensor of size 1x1]
#
#
#  0.7391
# [torch.FloatTensor of size 1x1]
#
#
#  0.9996
# [torch.FloatTensor of size 1x1]
#
#
#  0.9968
# [torch.FloatTensor of size 1x1]
#
#
#  0.9993
# [torch.FloatTensor of size 1x1]
#
#
#  0.9866
# [torch.FloatTensor of size 1x1]
#
#
#  0.9995
# [torch.FloatTensor of size 1x1]
#
#
#  0.9927
# [torch.FloatTensor of size 1x1]
#
#
#  0.9984
# [torch.FloatTensor of size 1x1]
#
#
#  0.9987
# [torch.FloatTensor of size 1x1]
#
#
#  0.9959
# [torch.FloatTensor of size 1x1]
#
#
#  0.8467
# [torch.FloatTensor of size 1x1]
#
#
#  0.9982
# [torch.FloatTensor of size 1x1]
#
#
#  0.9848
# [torch.FloatTensor of size 1x1]
#
#
#  0.9984
# [torch.FloatTensor of size 1x1]
#
#
#  0.9983
# [torch.FloatTensor of size 1x1]
#
#
#  0.9992
# [torch.FloatTensor of size 1x1]
#
#
#  0.9920
# [torch.FloatTensor of size 1x1]
#
#
#  0.9892
# [torch.FloatTensor of size 1x1]
#
#
#  0.9978
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9996
# [torch.FloatTensor of size 1x1]
#
#
#  0.9900
# [torch.FloatTensor of size 1x1]
#
#
#  0.9997
# [torch.FloatTensor of size 1x1]
#
#
#  0.9978
# [torch.FloatTensor of size 1x1]
#
#
#  0.9798
# [torch.FloatTensor of size 1x1]
#
#
#  0.9493
# [torch.FloatTensor of size 1x1]
#
#
#  0.9974
# [torch.FloatTensor of size 1x1]
#
#
#  0.5323
# [torch.FloatTensor of size 1x1]
#
#
#  0.9915
# [torch.FloatTensor of size 1x1]
#
#
#  0.9436
# [torch.FloatTensor of size 1x1]
#
#
#  0.9983
# [torch.FloatTensor of size 1x1]
#
#
#  0.9932
# [torch.FloatTensor of size 1x1]
#
#
#  0.9991
# [torch.FloatTensor of size 1x1]
#
#
#  1.0000
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9993
# [torch.FloatTensor of size 1x1]
#
#
#  0.9946
# [torch.FloatTensor of size 1x1]
#
#
#  0.9996
# [torch.FloatTensor of size 1x1]
#
#
#  0.9993
# [torch.FloatTensor of size 1x1]
#
#
#  0.9888
# [torch.FloatTensor of size 1x1]
#
#
#  0.9672
# [torch.FloatTensor of size 1x1]
#
#
#  0.9922
# [torch.FloatTensor of size 1x1]
#
#
#  0.9968
# [torch.FloatTensor of size 1x1]
#
#
#  0.9743
# [torch.FloatTensor of size 1x1]
#
#
#  0.9381
# [torch.FloatTensor of size 1x1]
#
#
#  0.6637
# [torch.FloatTensor of size 1x1]
#
#
#  0.8232
# [torch.FloatTensor of size 1x1]
#
#
#  0.7405
# [torch.FloatTensor of size 1x1]
#
# 400: D: 0.300464928150177/0.013231504708528519 G: 3.170238494873047 (Real: [4.0192792081832884, 1.2099572686062467], Fake: [1.5702294193208217, 0.92755739716534114])
#
#  0.9980
# [torch.FloatTensor of size 1x1]
#
#
#  0.9996
# [torch.FloatTensor of size 1x1]
#
#
#  0.9983
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9916
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9997
# [torch.FloatTensor of size 1x1]
#
#
#  0.9972
# [torch.FloatTensor of size 1x1]
#
#
#  0.9971
# [torch.FloatTensor of size 1x1]
#
#
#  0.9533
# [torch.FloatTensor of size 1x1]
#
#
#  0.9649
# [torch.FloatTensor of size 1x1]
#
#
#  0.9560
# [torch.FloatTensor of size 1x1]
#
#
#  0.8485
# [torch.FloatTensor of size 1x1]
#
#
#  0.7160
# [torch.FloatTensor of size 1x1]
#
#
#  0.5711
# [torch.FloatTensor of size 1x1]
#
#
#  0.8872
# [torch.FloatTensor of size 1x1]
#
#
#  0.6098
# [torch.FloatTensor of size 1x1]
#
#
#  0.9995
# [torch.FloatTensor of size 1x1]
#
#
#  0.9988
# [torch.FloatTensor of size 1x1]
#
#
#  0.9989
# [torch.FloatTensor of size 1x1]
#
#
#  0.9997
# [torch.FloatTensor of size 1x1]
#
#
#  0.9984
# [torch.FloatTensor of size 1x1]
#
#
#  0.9680
# [torch.FloatTensor of size 1x1]
#
#
#  0.9960
# [torch.FloatTensor of size 1x1]
#
#
#  0.9812
# [torch.FloatTensor of size 1x1]
#
#
#  0.9048
# [torch.FloatTensor of size 1x1]
#
#
#  0.9257
# [torch.FloatTensor of size 1x1]
#
#
#  0.6558
# [torch.FloatTensor of size 1x1]
#
#
#  0.8441
# [torch.FloatTensor of size 1x1]
#
#
#  0.8115
# [torch.FloatTensor of size 1x1]
#
#
#  0.9277
# [torch.FloatTensor of size 1x1]
#
#
#  0.9826
# [torch.FloatTensor of size 1x1]
#
#
#  0.5845
# [torch.FloatTensor of size 1x1]
#
#
#  0.9078
# [torch.FloatTensor of size 1x1]
#
#
#  0.9876
# [torch.FloatTensor of size 1x1]
#
#
#  0.9592
# [torch.FloatTensor of size 1x1]
#
#
#  0.9869
# [torch.FloatTensor of size 1x1]
#
#
#  0.9918
# [torch.FloatTensor of size 1x1]
#
#
#  0.9813
# [torch.FloatTensor of size 1x1]
#
#
#  0.9568
# [torch.FloatTensor of size 1x1]
#
#
#  0.9809
# [torch.FloatTensor of size 1x1]
#
#
#  0.4115
# [torch.FloatTensor of size 1x1]
#
#
#  0.9720
# [torch.FloatTensor of size 1x1]
#
#
#  0.6751
# [torch.FloatTensor of size 1x1]
#
#
#  0.7782
# [torch.FloatTensor of size 1x1]
#
#
#  0.9006
# [torch.FloatTensor of size 1x1]
#
#
#  0.7699
# [torch.FloatTensor of size 1x1]
#
#
#  0.4729
# [torch.FloatTensor of size 1x1]
#  0.9736
# [torch.FloatTensor of size 1x1]
#
#
#  0.9972
# [torch.FloatTensor of size 1x1]
#
#
#  0.9950
# [torch.FloatTensor of size 1x1]
#
#
#  0.9992
# [torch.FloatTensor of size 1x1]
#
#
#  0.9748
# [torch.FloatTensor of size 1x1]
#
#
#  0.9741
# [torch.FloatTensor of size 1x1]
#
#
#  0.9519
# [torch.FloatTensor of size 1x1]
#
#
#  0.2297
# [torch.FloatTensor of size 1x1]
#
#
#  0.9318
# [torch.FloatTensor of size 1x1]
#
#
#  0.6868
# [torch.FloatTensor of size 1x1]
#
#
#  0.9629
# [torch.FloatTensor of size 1x1]
#
#
#  0.9417
# [torch.FloatTensor of size 1x1]
#
#
#  0.9652
# [torch.FloatTensor of size 1x1]
#
#
#  0.9692
# [torch.FloatTensor of size 1x1]
#
#
#  0.9608
# [torch.FloatTensor of size 1x1]
#
#
#  0.9883
# [torch.FloatTensor of size 1x1]
#
#
#  0.9396
# [torch.FloatTensor of size 1x1]
#
#
#  0.9838
# [torch.FloatTensor of size 1x1]
#
#
#  0.9506
# [torch.FloatTensor of size 1x1]
#
#
#  0.9451
# [torch.FloatTensor of size 1x1]
#
#
#  0.8913
# [torch.FloatTensor of size 1x1]
#
#
#  0.9563
# [torch.FloatTensor of size 1x1]
#
#
#  0.9128
# [torch.FloatTensor of size 1x1]
#
#
#  0.8647
# [torch.FloatTensor of size 1x1]
#
#
#  0.9888
# [torch.FloatTensor of size 1x1]
#
#
#  0.8462
# [torch.FloatTensor of size 1x1]
#
#
#  0.9522
# [torch.FloatTensor of size 1x1]
#
#
#  0.9791
# [torch.FloatTensor of size 1x1]
#
#
#  0.9822
# [torch.FloatTensor of size 1x1]
#
#
#  0.6061
# [torch.FloatTensor of size 1x1]
#
#
#  0.9433
# [torch.FloatTensor of size 1x1]
#
#
#  0.9968
# [torch.FloatTensor of size 1x1]
#
#
#  0.9974
# [torch.FloatTensor of size 1x1]
#
#
#  0.9988
# [torch.FloatTensor of size 1x1]
#
#
#  0.9927
# [torch.FloatTensor of size 1x1]
#
#
#  0.8683
# [torch.FloatTensor of size 1x1]
#
#
#  0.9981
# [torch.FloatTensor of size 1x1]
#
#
#  0.9946
# [torch.FloatTensor of size 1x1]
#
#
#  0.9293
# [torch.FloatTensor of size 1x1]
#
#
#  0.9024
# [torch.FloatTensor of size 1x1]
#
#
# 1.00000e-02 *
#   5.1437
# [torch.FloatTensor of size 1x1]
#
#
#  0.9876
# [torch.FloatTensor of size 1x1]
#
#
#  0.9649
# [torch.FloatTensor of size 1x1]
#
#
#  0.9955
# [torch.FloatTensor of size 1x1]
#
#
#  0.9959
# [torch.FloatTensor of size 1x1]
#
#
#  0.9872
# [torch.FloatTensor of size 1x1]
#
#
#  0.9846
# [torch.FloatTensor of size 1x1]
#
#
#  0.9999
# [torch.FloatTensor of size 1x1]
#
#
#  0.9630
# [torch.FloatTensor of size 1x1]
#
#
#  0.9980
# [torch.FloatTensor of size 1x1]
#
#
#  0.9996
# [torch.FloatTensor of size 1x1]
#
#
#  0.8258
# [torch.FloatTensor of size 1x1]
#
#
#  0.4951
# [torch.FloatTensor of size 1x1]
#
#
#  0.9074
# [torch.FloatTensor of size 1x1]
#
#
#  0.9206
# [torch.FloatTensor of size 1x1]
#
#
#  0.9735
# [torch.FloatTensor of size 1x1]
#
#
#  0.9781
# [torch.FloatTensor of size 1x1]
#
#
#  0.7346
# [torch.FloatTensor of size 1x1]
#
#
#  0.8830
# [torch.FloatTensor of size 1x1]
#
#
#  0.9937
# [torch.FloatTensor of size 1x1]
#
#
#  0.8468
# [torch.FloatTensor of size 1x1]
#
#
#  0.9832
# [torch.FloatTensor of size 1x1]
#
#
#  0.9802
# [torch.FloatTensor of size 1x1]
#
#
#  0.7188
# [torch.FloatTensor of size 1x1]
#
#
#  0.9996
# [torch.FloatTensor of size 1x1]
#
#
#  0.9945
# [torch.FloatTensor of size 1x1]
#
#
#  0.8454
# [torch.FloatTensor of size 1x1]
#
#
#  0.9255
# [torch.FloatTensor of size 1x1]
#
#
#  0.9303
# [torch.FloatTensor of size 1x1]
#
#
#  0.5895
# [torch.FloatTensor of size 1x1]
#
#
#  0.3313
# [torch.FloatTensor of size 1x1]
#
#
#  0.9773
# [torch.FloatTensor of size 1x1]
#
#
#  0.9795
# [torch.FloatTensor of size 1x1]
#
#
#  0.9897
# [torch.FloatTensor of size 1x1]
#
#
#  0.8951
# [torch.FloatTensor of size 1x1]
#
#
#  0.7879
# [torch.FloatTensor of size 1x1]
#
#
#  0.9177
# [torch.FloatTensor of size 1x1]
#
#
#  0.8073
# [torch.FloatTensor of size 1x1]
#
#
#  0.4352
# [torch.FloatTensor of size 1x1]
#
#
#  0.9811
# [torch.FloatTensor of size 1x1]
#
#
#  0.2786
# [torch.FloatTensor of size 1x1]
#
#
#  0.8831
# [torch.FloatTensor of size 1x1]
#
#
#  0.5974
# [torch.FloatTensor of size 1x1]
#
#
#  0.4648
# [torch.FloatTensor of size 1x1]
#
#
#  0.9688
# [torch.FloatTensor of size 1x1]
#
#
#  0.8401
# [torch.FloatTensor of size 1x1]
#
#
#  0.9928
# [torch.FloatTensor of size 1x1]
#
#
#  0.9517
# [torch.FloatTensor of size 1x1]
#
#
#  0.8752
# [torch.FloatTensor of size 1x1]
#
#
#  0.9319
# [torch.FloatTensor of size 1x1]
#
#
#  0.3590
# [torch.FloatTensor of size 1x1]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-deeab19d1198> in <module>()
#       9         print(d_real_decision.data)
#      10         d_real_error = criterion(d_real_decision, Variable(torch.ones(1)))  # ones = true
# ---> 11         d_real_error.backward() # compute/store gradients, but don't change params
#      12
#      13         #  1B: Train D on fake
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/autograd/variable.py in backward(self, gradient, retain_variables)
#     144                     'or with gradient w.r.t. the variable')
#     145             gradient = self.data.new().resize_as_(self.data).fill_(1)
# --> 146         self._execution_engine.run_backward((self,), (gradient,), retain_variables)
#     147
#     148     def register_hook(self, hook):
#
# KeyboardInterrupt:
